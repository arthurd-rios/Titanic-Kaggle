# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tab = pd.crosstab(df['Pclass'], df['Survived'])

print(tab)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
for pclass, line in tab.iterrows():

    not_survived = line[0]
    survived = line[1]

    print(f"Survival rate for class {pclass}: {100*survived/(survived+not_survived):.2f}%")

# The higher the class, the higher the survival rate
# Out:
# Survival rate for class 1: 62.96%
# Survival rate for class 2: 47.28%
# Survival rate for class 3: 24.24%

# %%
tab = pd.crosstab(df['Sex'], df['Survived'])

print(tab)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
for Sex, line in tab.iterrows():

    not_survived = line[0]
    survived = line[1]

    print(f"Survival rate for {Sex}: {100*survived/(survived+not_survived):.2f}%")

# Female has higher survival rate (they tried to save more womans and girls)
# Out:
# Survival rate for female: 74.20%
# Survival rate for male: 18.89%

# %%
conditions = [
    (df['Age'] < 12),
    (df['Age'] >= 12) & (df['Age'] < 18),
    (df['Age'] >= 18) & (df['Age'] < 60),
    (df['Age'] >= 60)
]

group = ['kid', 'teen', 'adult', 'elderly']

df['AgeGroup'] = np.select(conditions, group, default='unknown')

# %%
tab = pd.crosstab(df['AgeGroup'], df['Survived'])

print(tab)
# Out:
# Survived    0    1
# AgeGroup
# adult     353  222
# elderly    19    7
# kid        29   39
# teen       23   22
# unknown   125   52

# %%
for AgeGroup, line in tab.iterrows():

    not_survived = line[0]
    survived = line[1]

    print(f"Survival rate for age group {AgeGroup}: {100*survived/(survived+not_survived):.2f}%")

# The younger the age group, the higher the survival rate (they tried to save more kids and teens)
# Out:
# Survival rate for age group adult: 38.61%
# Survival rate for age group elderly: 26.92%
# Survival rate for age group kid: 57.35%
# Survival rate for age group teen: 48.89%
# Survival rate for age group unknown: 29.38%

# %%
print(df['Name'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
df['NameTitle'] = df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)

# %%
df['NameTitle'].value_counts()
# Out:
# NameTitle
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Don           1
# Mme           1
# Ms            1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
mask = df['AgeGroup'] == 'unknown'

df.loc[mask, 'NameTitle'].value_counts()

# Mr = Adult
# Miss = Woman
# Mrs = Adult
# Master = Kid
# Dr = Probably adult, but maybe Elderly
# Out:
# NameTitle
# Mr        119
# Miss       36
# Mrs        17
# Master      4
# Dr          1
# Name: count, dtype: int64
